# %%
import pandas as pd
import random
from random import sample

# %%
items = pd.read_csv('/media/akhmadiev/528807968807782D/Develop/PycharmProjects/RecoServiceTemplate-master/service/data/kion_train/kion_train/interactions.csv')[['user_id', 'item_id']]

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5476251 entries, 0 to 5476250
# Data columns (total 2 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  int64
#  1   item_id  int64
# dtypes: int64(2)
# memory usage: 83.6 MB

# %%
items[items['user_id'] == 656683].sort_values(by='item_id')['item_id'].values
# Out:
# array([ 7107,  8636, 14741])

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5476251 entries, 0 to 5476250
# Data columns (total 2 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  int64
#  1   item_id  int64
# dtypes: int64(2)
# memory usage: 83.6 MB

# %%
a = items[items['user_id'] == 656683]['item_id'].values

# %%
a = items.groupby('user_id').agg({'item_id':lambda x: sorted(list(x))})

# %%
rec = list(a[a.index == 33]['item_id'])

if len(rec) == 0:
    rec = random.choices(items_list, k=k_recs)

rec#[0][:10]
# Out:
# [6470, 8943, 15374, 1707, 15374, 15255, 16299, 10120, 13070, 10837]

# %%
k_recs = 10
items_list = list((items['item_id'].unique()))
rec = list(a[a.index == 28981]['item_id'])[0][:k_recs]
if len(rec) < k_recs:
    rec.extend(shuffle(list(set(items_list) - set(rec)))[:k_recs - len(rec)])

rec
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [96], line 5
#       3 rec = list(a[a.index == 28981]['item_id'])[0][:k_recs]
#       4 if len(rec) < k_recs:
# ----> 5     rec.extend(shuffle(list(set(items_list) - set(rec)))[:k_recs - len(rec)])
#       7 rec
#
# TypeError: 'NoneType' object is not subscriptable

# %%
ll
# Out:
# [10261,
#  12355,
#  15401,
#  15540,
#  12069,
#  5564,
#  9014,
#  8973,
#  4174,
#  11688,
#  9050,
#  14991,
#  16451,
#  7451,
#  13998,
#  2202,
#  8592,
#  2015,
#  4226,
#  10221,
#  2371,
#  15112,
#  15155,
#  5051,
#  14217,
#  9094,
#  5261,
#  15759,
#  15503,
#  6239,
#  298,
#  3854,
#  12556,
#  9966,
#  15498,
#  11831,
#  5737,
#  16228,
#  9212,
#  14040,
#  13817,
#  12495,
#  1643,
#  9099,
#  8943,
#  6746,
#  2854,
#  5435,
#  8120,
#  12874,
#  2327,
#  10359,
#  10581,
#  1764,
#  9722,
#  10594,
#  5863,
#  4819,
#  7955,
#  8354,
#  11235,
#  10253,
#  7399,
#  1130,
#  12398,
#  14504,
#  160,
#  14607,
#  2187,
#  4151,
#  13211,
#  598,
#  1346,
#  14960,
#  10271,
#  5140,
#  15376,
#  4936,
#  11720,
#  16313,
#  5228,
#  5949,
#  16385,
#  4698,
#  11729,
#  14182,
#  1654,
#  16285,
#  3346,
#  9745,
#  6722,
#  2165,
#  12065,
#  4856,
#  13541,
#  3071,
#  14958,
#  9938,
#  9690,
#  13333,
#  2439,
#  16124,
#  11547,
#  7334,
#  6187,
#  9296,
# ...

# %%
ll = list(set(items_list) - set(rec))
print(sample(ll, 4))
# Out:
# [8048, 10998, 13459, 9979]

# %%
rec.extend(shuffle(list(set(items_list) - set(rec)))[:k_recs - len(rec)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [88], line 1
# ----> 1 rec.extend(shuffle(list(set(items_list) - set(rec)))[:k_recs - len(rec)])
#
# TypeError: unhashable type: 'list'

# %%
# Out:
# [7107, 8636, 14741]
